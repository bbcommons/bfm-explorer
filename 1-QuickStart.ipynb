# %% [markdown]
# # Broadband Funding Map
#
# This notebook will run through the national Broadband Funding Map APIs. For more background on the national Broadband Funding Map please go *here*
#
# ## Getting setup
#
# Install requests if not already available.

# %%
# !pip install requests pandas itables
# Out:
# Requirement already satisfied: requests in c:\users\nick.pappin\projects\bfm-explorer\venv\lib\site-packages (2.31.0)
# Requirement already satisfied: pandas in c:\users\nick.pappin\projects\bfm-explorer\venv\lib\site-packages (2.0.3)
# Collecting itables
#   Downloading itables-1.5.3-py3-none-any.whl (199 kB)
#                                               0.0/199.3 kB ? eta -:--:--
#      ------                                  30.7/199.3 kB 1.4 MB/s eta 0:00:01
#      -----------                           61.4/199.3 kB 550.5 kB/s eta 0:00:01
#      -----------------                     92.2/199.3 kB 751.6 kB/s eta 0:00:01
#      -------------------------            143.4/199.3 kB 711.9 kB/s eta 0:00:01
#      -------------------------------      174.1/199.3 kB 700.2 kB/s eta 0:00:01
#      ------------------------------------ 199.3/199.3 kB 756.1 kB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\nick.pappin\projects\bfm-explorer\venv\lib\site-packages (from requests) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nick.pappin\projects\bfm-explorer\venv\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nick.pappin\projects\bfm-explorer\venv\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nick.pappin\projects\bfm-explorer\venv\lib\site-packages (from requests) (2023.7.22)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\nick.pappin\projects\bfm-explorer\venv\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\nick.pappin\projects\bfm-explorer\venv\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\nick.pappin\projects\bfm-explorer\venv\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\nick.pappin\projects\bfm-explorer\venv\lib\site-packages (from pandas) (1.25.2)
# Requirement already satisfied: IPython in c:\users\nick.pappin\projects\bfm-explorer\venv\lib\site-packages (from itables) (8.14.0)
# Requirement already satisfied: six>=1.5 in c:\users\nick.pappin\projects\bfm-explorer\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: backcall in c:\users\nick.pappin\projects\bfm-explorer\venv\lib\site-packages (from IPython->itables) (0.2.0)
# Requirement already satisfied: decorator in c:\users\nick.pappin\projects\bfm-explorer\venv\lib\site-packages (from IPython->itables) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\nick.pappin\projects\bfm-explorer\venv\lib\site-packages (from IPython->itables) (0.19.0)
# Requirement already satisfied: matplotlib-inline in c:\users\nick.pappin\projects\bfm-explorer\venv\lib\site-packages (from IPython->itables) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\nick.pappin\projects\bfm-explorer\venv\lib\site-packages (from IPython->itables) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\nick.pappin\projects\bfm-explorer\venv\lib\site-packages (from IPython->itables) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\nick.pappin\projects\bfm-explorer\venv\lib\site-packages (from IPython->itables) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\nick.pappin\projects\bfm-explorer\venv\lib\site-packages (from IPython->itables) (0.6.2)
# Requirement already satisfied: traitlets>=5 in c:\users\nick.pappin\projects\bfm-explorer\venv\lib\site-packages (from IPython->itables) (5.9.0)
# Requirement already satisfied: colorama in c:\users\nick.pappin\projects\bfm-explorer\venv\lib\site-packages (from IPython->itables) (0.4.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\nick.pappin\projects\bfm-explorer\venv\lib\site-packages (from jedi>=0.16->IPython->itables) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\nick.pappin\projects\bfm-explorer\venv\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->IPython->itables) (0.2.6)
# Requirement already satisfied: executing>=1.2.0 in c:\users\nick.pappin\projects\bfm-explorer\venv\lib\site-packages (from stack-data->IPython->itables) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\nick.pappin\projects\bfm-explorer\venv\lib\site-packages (from stack-data->IPython->itables) (2.2.1)
# Requirement already satisfied: pure-eval in c:\users\nick.pappin\projects\bfm-explorer\venv\lib\site-packages (from stack-data->IPython->itables) (0.2.2)
# Installing collected packages: itables
# Successfully installed itables-1.5.3
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Do the imports

# %%
import requests, json, itables
from pprint import pprint
import pandas as pd

itables.init_notebook_mode(all_interactive=False)
itables.options.maxBytes = 0
# Out:
# <script>
#   // Create a pending promise immediately (this script is not deferred).
#   window.dataTablePromise = new Promise((resolve) => {
#     window.__resolveDataTablePromise__ = resolve;
#   });
# </script>
# <script type="module">
#   // Module scripts are automatically deferred, so this code will not execute immediately.
#   // See https://developer.mozilla.org/en-US/docs/Web/JavaScript/Guide/Modules#other_differences_between_modules_and_standard_scripts
#   if ($.prototype.DataTable === undefined) {
#       const dt = (await import("data:text/javascript;base64,...")).default;
#       dt(window.$);
#       // Resolve the pending promise above, indicating that DataTable is now ready to be used.
#       window.__resolveDataTablePromise__();
#   }
# </script>
# <style>table.dataTable td.dt-control{text-align:center;cursor:pointer}table.dataTable td.dt-control:before{height:1em;width:1em;margin-top:-9px;display:inline-block;color:white;border:.15em solid white;border-radius:1em;box-shadow:0 0 .2em #444;box-sizing:content-box;text-align:center;text-indent:0 !important;font-family:"Courier New",Courier,monospace;line-height:1em;content:"+";background-color:#31b131}table.dataTable tr.dt-hasChild td.dt-control:before{content:"-";background-color:#d33333}table.dataTable thead>tr>th.sorting,table.dataTable thead>tr>th.sorting_asc,table.dataTable thead>tr>th.sorting_desc,table.dataTable thead>tr>th.sorting_asc_disabled,table.dataTable thead>tr>th.sorting_desc_disabled,table.dataTable thead>tr>td.sorting,table.dataTable thead>tr>td.sorting_asc,table.dataTable thead>tr>td.sorting_desc,table.dataTable thead>tr>td.sorting_asc_disabled,table.dataTable thead>tr>td.sorting_desc_disabled{cursor:pointer;position:relative;padding-right:26px}table.dataTable thead>tr>th.sorting:before,table.dataTable thead>tr>th.sorting:after,table.dataTable thead>tr>th.sorting_asc:before,table.dataTable thead>tr>th.sorting_asc:after,table.dataTable thead>tr>th.sorting_desc:before,table.dataTable thead>tr>th.sorting_desc:after,table.dataTable thead>tr>th.sorting_asc_disabled:before,table.dataTable thead>tr>th.sorting_asc_disabled:after,table.dataTable thead>tr>th.sorting_desc_disabled:before,table.dataTable thead>tr>th.sorting_desc_disabled:after,table.dataTable thead>tr>td.sorting:before,table.dataTable thead>tr>td.sorting:after,table.dataTable thead>tr>td.sorting_asc:before,table.dataTable thead>tr>td.sorting_asc:after,table.dataTable thead>tr>td.sorting_desc:before,table.dataTable thead>tr>td.sorting_desc:after,table.dataTable thead>tr>td.sorting_asc_disabled:before,table.dataTable thead>tr>td.sorting_asc_disabled:after,table.dataTable thead>tr>td.sorting_desc_disabled:before,table.dataTable thead>tr>td.sorting_desc_disabled:after{position:absolute;display:block;opacity:.125;right:10px;line-height:9px;font-size:.8em}table.dataTable thead>tr>th.sorting:before,table.dataTable thead>tr>th.sorting_asc:before,table.dataTable thead>tr>th.sorting_desc:before,table.dataTable thead>tr>th.sorting_asc_disabled:before,table.dataTable thead>tr>th.sorting_desc_disabled:before,table.dataTable thead>tr>td.sorting:before,table.dataTable thead>tr>td.sorting_asc:before,table.dataTable thead>tr>td.sorting_desc:before,table.dataTable thead>tr>td.sorting_asc_disabled:before,table.dataTable thead>tr>td.sorting_desc_disabled:before{bottom:50%;content:"▲"}table.dataTable thead>tr>th.sorting:after,table.dataTable thead>tr>th.sorting_asc:after,table.dataTable thead>tr>th.sorting_desc:after,table.dataTable thead>tr>th.sorting_asc_disabled:after,table.dataTable thead>tr>th.sorting_desc_disabled:after,table.dataTable thead>tr>td.sorting:after,table.dataTable thead>tr>td.sorting_asc:after,table.dataTable thead>tr>td.sorting_desc:after,table.dataTable thead>tr>td.sorting_asc_disabled:after,table.dataTable thead>tr>td.sorting_desc_disabled:after{top:50%;content:"▼"}table.dataTable thead>tr>th.sorting_asc:before,table.dataTable thead>tr>th.sorting_desc:after,table.dataTable thead>tr>td.sorting_asc:before,table.dataTable thead>tr>td.sorting_desc:after{opacity:.6}table.dataTable thead>tr>th.sorting_desc_disabled:after,table.dataTable thead>tr>th.sorting_asc_disabled:before,table.dataTable thead>tr>td.sorting_desc_disabled:after,table.dataTable thead>tr>td.sorting_asc_disabled:before{display:none}table.dataTable thead>tr>th:active,table.dataTable thead>tr>td:active{outline:none}div.dataTables_scrollBody table.dataTable thead>tr>th:before,div.dataTables_scrollBody table.dataTable thead>tr>th:after,div.dataTables_scrollBody table.dataTable thead>tr>td:before,div.dataTables_scrollBody table.dataTable thead>tr>td:after{display:none}div.dataTables_processing{position:absolute;top:50%;left:50%;width:200px;margin-left:-100px;margin-top:-26px;text-align:center; ...

# %% [markdown]
# ## Get the current UUID
#
# We may still be subject to rate limiting. Lets check!

# %%
url = "https://fundingmap.fcc.gov/bfm/api/map/getPublishedRun"
r = requests.get(url, timeout=5)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File c:\Users\nick.pappin\projects\bfm-explorer\venv\Lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#
# File c:\Users\nick.pappin\projects\bfm-explorer\venv\Lib\site-packages\urllib3\connection.py:461, in HTTPConnection.getresponse(self)
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.1264.0_x64__qbz5n2kfra8p0\Lib\http\client.py:1378, in HTTPConnection.getresponse(self)
#    1377 try:
# -> 1378     response.begin()
#    1379 except ConnectionError:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.1264.0_x64__qbz5n2kfra8p0\Lib\http\client.py:318, in HTTPResponse.begin(self)
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.1264.0_x64__qbz5n2kfra8p0\Lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.1264.0_x64__qbz5n2kfra8p0\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     705 try:
# --> 706     return self._sock.recv_into(b)
#     707 except timeout:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.1264.0_x64__qbz5n2kfra8p0\Lib\ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.1264.0_x64__qbz5n2kfra8p0\Lib\ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1133 if buffer is not None:
# -> 1134     return self._sslobj.read(len, buffer)
#    1135 else:
#
# TimeoutError: The read operation timed out
#
# The above exception was the direct cause of the following exception:
#
# ReadTimeoutError                          Traceback (most recent call last)
# File c:\Users\nick.pappin\projects\bfm-explorer\venv\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File c:\Users\nick.pappin\projects\bfm-explorer\venv\Lib\site-packages\urllib3\connectionpool.py:844, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     842     new_e = ProtocolError("Connection aborted.", new_e)
# --> 844 retries = retries.increment(
#     845     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     846 )
#     847 retries.sleep()
#
# File c:\Users\nick.pappin\projects\bfm-explorer\venv\Lib\site-packages\urllib3\util\retry.py:470, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     469 if read is False or method is None or not self._is_method_retryable(method):
# --> 470     raise reraise(type(error), error, _stacktrace)
#     471 elif read is not None:
#
# File c:\Users\nick.pappin\projects\bfm-explorer\venv\Lib\site-packages\urllib3\util\util.py:39, in reraise(tp, value, tb)
#      38         raise value.with_traceback(tb)
# ---> 39     raise value
#      40 finally:
#
# File c:\Users\nick.pappin\projects\bfm-explorer\venv\Lib\site-packages\urllib3\connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#
# File c:\Users\nick.pappin\projects\bfm-explorer\venv\Lib\site-packages\urllib3\connectionpool.py:538, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     537 except (BaseSSLError, OSError) as e:
# --> 538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     539     raise
#
# File c:\Users\nick.pappin\projects\bfm-explorer\venv\Lib\site-packages\urllib3\connectionpool.py:370, in HTTPConnectionPool._raise_timeout(self, err, url, timeout_value)
#     369 if isinstance(err, SocketTimeout):
# --> 370     raise ReadTimeoutError(
#     371         self, url, f"Read timed out. (read timeout={timeout_value})"
#     372     ) from err
#     374 # See the above comment about EAGAIN in Python 3.
#
# ReadTimeoutError: HTTPSConnectionPool(host='fundingmap.fcc.gov', port=443): Read timed out. (read timeout=5)
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeout                               Traceback (most recent call last)
# Cell In[40], line 2
#       1 url = "https://fundingmap.fcc.gov/bfm/api/map/getPublishedRun"
# ----> 2 r = requests.get(url, timeout=5)
#
# File c:\Users\nick.pappin\projects\bfm-explorer\venv\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\nick.pappin\projects\bfm-explorer\venv\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\nick.pappin\projects\bfm-explorer\venv\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\nick.pappin\projects\bfm-explorer\venv\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\nick.pappin\projects\bfm-explorer\venv\Lib\site-packages\requests\adapters.py:532, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     530     raise SSLError(e, request=request)
#     531 elif isinstance(e, ReadTimeoutError):
# --> 532     raise ReadTimeout(e, request=request)
#     533 elif isinstance(e, _InvalidHeader):
#     534     raise InvalidHeader(e, request=request)
#
# ReadTimeout: HTTPSConnectionPool(host='fundingmap.fcc.gov', port=443): Read timed out. (read timeout=5)

# %% [markdown]
# Yep... lets implement a session and set our header, and try to get the published run.

# %%
s = requests.Session()
s.headers.update({'User-Agent': 'bfm-explorer 0.0.1'})

r = s.get(url)

# %% [markdown]
# Cool, it worked lets move on.
#
# Lets get the published run information.

# %%
print(url)

r = s.get(url)
# Out:
# https://fundingmap.fcc.gov/bfm/api/map/getPublishedRun

# %% [markdown]
# And parse it pulling out the uuid.

# %%
parsed = json.loads(r.content)

pprint(parsed)

uuid = parsed['data'][0]['process_uuid']

print(f'\nUUID: {uuid}')
# Out:
# {'data': [{'create_date': '2023-08-02',
#            'home_page_config': 'br=r&speed=25_3&tech=1_2_3_6_7',
#            'nbm_create_date': '2023-07-25',
#            'nbm_data_as_of_date': '2022-12-31',
#            'nbm_process_uuid': '2750f3d2-3b48-4a96-9e52-2a21eb79d5ed',
#            'process_uuid': '50b888a0-df10-40bb-ac6e-893caa3a8b3c'}],
#  'message': None,
#  'request_date': '2023-08-03T16:45:52.461Z',
#  'result_count': 1,
#  'status': 'successful',
#  'status_code': 200}
#
# UUID: 50b888a0-df10-40bb-ac6e-893caa3a8b3c

# %% [markdown]
# ## Funding Agencies
#
# This is a pretty easy and straight forward one.

# %%
url = f"https://fundingmap.fcc.gov/bfm/api/map/getAgencyList/{uuid}"

r = s.get(url)

parsed = json.loads(r.content)

parsed
# Out:
# {'data': [{'id': '1', 'agency_name': 'Federal Communications Commission'},
#   {'id': '5', 'agency_name': 'NTIA'},
#   {'id': '3', 'agency_name': 'Rural Utilities Service'},
#   {'id': '4', 'agency_name': 'US Department of Treasury'}],
#  'result_count': 4,
#  'status_code': 200,
#  'message': None,
#  'status': 'successful',
#  'request_date': '2023-08-03T17:36:46.076Z'}

# %% [markdown]
# Lets get a list of Agencies.

# %%
agencies = [item['agency_name'] for item in parsed['data']]

agencies
# Out:
# ['Federal Communications Commission',
#  'NTIA',
#  'Rural Utilities Service',
#  'US Department of Treasury']

# %% [markdown]
# ## Programs
#
# Lets find out what programs are available.

# %%
url = f"https://fundingmap.fcc.gov/bfm/api/map/getDataDownload/{uuid}"

r = s.get(url)

parsed = json.loads(r.content)

parsed
# Out:
# {'data': [{'id': 11036,
#    'data_category': 'Funding Data',
#    'data_type': 'Program',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 25,
#    'program_name': 'Bringing Puerto Rico Together',
#    'project_id': None,
#    'project_name': None,
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_program25_20230803',
#    'download_available': 'Yes'},
#   {'id': 11041,
#    'data_category': 'Funding Data',
#    'data_type': 'Program',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': None,
#    'project_name': None,
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_program28_20230803',
#    'download_available': 'Yes'},
#   {'id': 11037,
#    'data_category': 'Funding Data',
#    'data_type': 'Program',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 26,
#    'program_name': 'Connect USVI',
#    'project_id': None,
#    'project_name': None,
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_program26_20230803',
#    'download_available': 'Yes'},
#   {'id': 11042,
#    'data_category': 'Funding Data',
#    'data_type': 'Program',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 24,
#    'program_name': 'Rural Digital Opportunity Fund',
#    'project_id': None,
#    'project_name': None,
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_program24_20230803',
#    'download_available': 'Yes'},
#   {'id': 11039,
#    'data_category': 'Funding Data',
#    'data_type': 'Program',
#    'agency_id': 5,
#    'agency_name': 'NTIA',
#    'program_id': 11,
#    'program_name': 'Broadband Infrastructure Program',
#    'project_id': None,
#    'project_name': None,
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_program11_20230803',
#    'download_available': 'Yes'},
#   {'id': 11040,
#    'data_category': 'Funding Data',
#    'data_type': 'Program',
#    'agency_id': 5,
#    'agency_name': 'NTIA',
#    'program_id': 27,
#    'program_name': 'Tribal Broadband Connectivity Program NOFO 1',
#    'project_id': None,
#    'project_name': None,
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_program27_20230803',
#    'download_available': 'Yes'},
#   {'id': 11038,
#    'data_category': 'Funding Data',
#    'data_type': 'Program',
#    'agency_id': 3,
#    'agency_name': 'Rural Utilities Service',
#    'program_id': 10,
#    'program_name': 'COMMUNITY CONNECT GRANT PROGRAM',
#    'project_id': None,
#    'project_name': None,
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_program10_20230803',
#    'download_available': 'Yes'},
#   {'id': 11035,
#    'data_category': 'Funding Data',
#    'data_type': 'Program',
#    'agency_id': 3,
#    'agency_name': 'Rural Utilities Service',
#    'program_id': 6,
#    'program_name': 'RURAL ECONNECTIVITY PROGRAM',
#    'project_id': None,
#    'project_name': None,
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_program6_20230803',
#    'download_available': 'Yes'},
#   {'id': 11033,
#    'data_category': 'Funding Data',
#    'data_type': 'Program',
#    'agency_id': 3,
#    'agency_name': 'Rural Utilities Service',
#    'program_id': 12,
#    'program_name': 'TELEPHONE LOAN PROGRAM',
#    'project_id': None,
#    'project_name': None,
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_program12_20230803',
#    'download_available': 'Yes'},
#   {'id': 11034,
#    'data_category': 'Funding Data',
#    'data_type': 'Program',
#    'agency_id': 4,
#    'agency_name': 'US Department of Treasury',
#    'program_id': 18,
#    'program_name': 'Capital Projects Fund',
#    'project_id': None,
#    'project_name': None,
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_program18_20230803',
#    'download_available': 'Yes'},
#   {'id': 11466,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 25,
#    'program_name': 'Bringing Puerto Rico Together',
#    'project_id': 4259,
#    'project_name': 'Liberty Communications - PR - Above Baseline (Tranche: Stage 2)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4259_20230803',
#    'download_available': 'Yes'},
#   {'id': 11467,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 25,
#    'program_name': 'Bringing Puerto Rico Together',
#    'project_id': 4260,
#    'project_name': 'Liberty Communications - PR - Gigabit (Tranche: Stage 2)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4260_20230803',
#    'download_available': 'Yes'},
#   {'id': 11468,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 25,
#    'program_name': 'Bringing Puerto Rico Together',
#    'project_id': 4261,
#    'project_name': 'Puerto Rico Telephone Co. - PR - Above Baseline (Tranche: Stage 2)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4261_20230803',
#    'download_available': 'Yes'},
#   {'id': 11469,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 25,
#    'program_name': 'Bringing Puerto Rico Together',
#    'project_id': 4262,
#    'project_name': 'Puerto Rico Telephone Co. - PR - Gigabit (Tranche: Stage 2)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4262_20230803',
#    'download_available': 'Yes'},
#   {'id': 11470,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4263,
#    'project_name': '3E8 Broadband Solutions, LLC - AR - Gigabit (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4263_20230803',
#    'download_available': 'Yes'},
#   {'id': 11477,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4270,
#    'project_name': 'Air Link Rural Broadband, LLC - MO - Above Baseline (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4270_20230803',
#    'download_available': 'Yes'},
#   {'id': 11478,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4271,
#    'project_name': "Allen's T.V. Cable Service, Inc. - LA - Gigabit (Tranche: Phase II)",
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4271_20230803',
#    'download_available': 'Yes'},
#   {'id': 11471,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4264,
#    'project_name': 'AMG Technology Investment Group LLC - IA - Above Baseline (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4264_20230803',
#    'download_available': 'Yes'},
#   {'id': 11472,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4265,
#    'project_name': 'AMG Technology Investment Group LLC - IL - Above Baseline (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4265_20230803',
#    'download_available': 'Yes'},
#   {'id': 11473,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4266,
#    'project_name': 'AMG Technology Investment Group LLC - KS - Above Baseline (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4266_20230803',
#    'download_available': 'Yes'},
#   {'id': 11474,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4267,
#    'project_name': 'AMG Technology Investment Group LLC - NE - Above Baseline (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4267_20230803',
#    'download_available': 'Yes'},
#   {'id': 11475,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4268,
#    'project_name': 'AMG Technology Investment Group LLC - OK - Above Baseline (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4268_20230803',
#    'download_available': 'Yes'},
#   {'id': 11476,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4269,
#    'project_name': 'AMG Technology Investment Group LLC - TX - Above Baseline (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4269_20230803',
#    'download_available': 'Yes'},
#   {'id': 11527,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4321,
#    'project_name': 'Armstrong Telecommunications, Inc. - PA - Gigabit (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4321_20230803',
#    'download_available': 'Yes'},
#   {'id': 11479,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4272,
#    'project_name': 'BARConnects, LLC - VA - Gigabit (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4272_20230803',
#    'download_available': 'Yes'},
#   {'id': 11481,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4274,
#    'project_name': 'Barry Technology Services, LLC - MO - Gigabit (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4274_20230803',
#    'download_available': 'Yes'},
#   {'id': 11480,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4273,
#    'project_name': 'BEK Communications Cooperative - ND - Gigabit (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4273_20230803',
#    'download_available': 'Yes'},
#   {'id': 11482,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4275,
#    'project_name': 'Ben Lomand Communications, LLC - TN - Gigabit (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4275_20230803',
#    'download_available': 'Yes'},
#   {'id': 11483,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4276,
#    'project_name': 'Broadband Corp - MN - Above Baseline (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4276_20230803',
#    'download_available': 'Yes'},
#   {'id': 11484,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4277,
#    'project_name': 'Bruce Telephone Company, Inc. - WI - Gigabit (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4277_20230803',
#    'download_available': 'Yes'},
#   {'id': 11486,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4279,
#    'project_name': 'California Internet, L.P. - CA - Above Baseline (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4279_20230803',
#    'download_available': 'Yes'},
#   {'id': 11487,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4280,
#    'project_name': 'California Internet, L.P. - NV - Above Baseline (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4280_20230803',
#    'download_available': 'Yes'},
#   {'id': 11488,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4281,
#    'project_name': 'Callabyte Technology, LLC - MO - Gigabit (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4281_20230803',
#    'download_available': 'Yes'},
#   {'id': 11485,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4278,
#    'project_name': 'Cal.net, Inc. - CA - Above Baseline (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4278_20230803',
#    'download_available': 'Yes'},
#   {'id': 11489,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4282,
#    'project_name': 'Casey Mutual Telephone Company - IA - Gigabit (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4282_20230803',
#    'download_available': 'Yes'},
#   {'id': 11490,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4283,
#    'project_name': 'Central Virginia Services, Inc. - VA - Gigabit (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4283_20230803',
#    'download_available': 'Yes'},
#   {'id': 11491,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4284,
#    'project_name': 'Chariton Valley Communications Corporation - MO - Gigabit (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4284_20230803',
#    'download_available': 'Yes'},
#   {'id': 11492,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4285,
#    'project_name': 'Cim Tel Cable, L.L.C. - OK - Above Baseline (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4285_20230803',
#    'download_available': 'Yes'},
#   {'id': 11493,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4286,
#    'project_name': 'Cim Tel Cable, L.L.C. - OK - Gigabit (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4286_20230803',
#    'download_available': 'Yes'},
#   {'id': 11494,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4287,
#    'project_name': 'Cincinnati Bell Extended Territories LLC - OH - Gigabit (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4287_20230803',
#    'download_available': 'Yes'},
#   {'id': 11495,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4288,
#    'project_name': 'Cincinnati Bell Telephone Company LLC - KY - Gigabit (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4288_20230803',
#    'download_available': 'Yes'},
#   {'id': 11496,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4289,
#    'project_name': 'Cincinnati Bell Telephone Company LLC - OH - Gigabit (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4289_20230803',
#    'download_available': 'Yes'},
#   {'id': 11497,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4290,
#    'project_name': 'Citynet West Virginia, LLC - WV - Gigabit (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4290_20230803',
#    'download_available': 'Yes'},
#   {'id': 11498,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4291,
#    'project_name': 'Co-Mo Comm, Inc. - MO - Gigabit (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4291_20230803',
#    'download_available': 'Yes'},
#   {'id': 11499,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4292,
#    'project_name': 'Consolidated Telephone Company - MN - Gigabit (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4292_20230803',
#    'download_available': 'Yes'},
#   {'id': 11500,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4293,
#    'project_name': 'Cross Cable Television, L.L.C. - OK - Gigabit (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4293_20230803',
#    'download_available': 'Yes'},
#   {'id': 11501,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4294,
#    'project_name': 'Cross Wireless, L.L.C. - OK - Above Baseline (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4294_20230803',
#    'download_available': 'Yes'},
#   {'id': 11502,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4295,
#    'project_name': 'Crystal Automation Systems, Inc. - MI - Above Baseline (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4295_20230803',
#    'download_available': 'Yes'},
#   {'id': 11503,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4296,
#    'project_name': 'Crystal Automation Systems, Inc. - MI - Gigabit (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4296_20230803',
#    'download_available': 'Yes'},
#   {'id': 11504,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4297,
#    'project_name': 'Douglas Services, Inc. - OR - Gigabit (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4297_20230803',
#    'download_available': 'Yes'},
#   {'id': 11518,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4312,
#    'project_name': 'ECO Services, LLC - OK - Gigabit (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4312_20230803',
#    'download_available': 'Yes'},
#   {'id': 11505,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4298,
#    'project_name': 'EMPOWER Broadband, Inc. - VA - Gigabit (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4298_20230803',
#    'download_available': 'Yes'},
#   {'id': 11506,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4299,
#    'project_name': 'Farmers Mutual Telephone Company - MN - Gigabit (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4299_20230803',
#    'download_available': 'Yes'},
#   {'id': 11507,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4300,
#    'project_name': 'Federated Telephone Cooperative - MN - Gigabit (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4300_20230803',
#    'download_available': 'Yes'},
#   {'id': 11508,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4302,
#    'project_name': 'Frontier California Inc - CA - Above Baseline (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4302_20230803',
#    'download_available': 'Yes'},
#   {'id': 11509,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4303,
#    'project_name': 'Garden Valley Telephone Company - MN - Gigabit (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4303_20230803',
#    'download_available': 'Yes'},
#   {'id': 11510,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4304,
#    'project_name': 'Gibson Connect, LLC - KY - Gigabit (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4304_20230803',
#    'download_available': 'Yes'},
#   {'id': 11511,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4305,
#    'project_name': 'Gibson Connect, LLC - TN - Gigabit (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4305_20230803',
#    'download_available': 'Yes'},
#   {'id': 11562,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4358,
#    'project_name': 'GoSEMO, LLC - MO - Gigabit (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4358_20230803',
#    'download_available': 'Yes'},
#   {'id': 11563,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4359,
#    'project_name': 'Great Lakes Energy Connections, Inc. - MI - Gigabit (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4359_20230803',
#    'download_available': 'Yes'},
#   {'id': 11564,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4360,
#    'project_name': 'Halstad Telephone Company - MN - Gigabit (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4360_20230803',
#    'download_available': 'Yes'},
#   {'id': 11565,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4361,
#    'project_name': 'Hardy Telecommunications, Inc  (CLEC) - WV - Gigabit (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4361_20230803',
#    'download_available': 'Yes'},
#   {'id': 11566,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4362,
#    'project_name': 'Hawaiian Telcom, Inc. - HI - Gigabit (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4362_20230803',
#    'download_available': 'Yes'},
#   {'id': 11519,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4313,
#    'project_name': 'Heartland Telecommunications Company of Iowa - IA - Gigabit (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4313_20230803',
#    'download_available': 'Yes'},
#   {'id': 11520,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4314,
#    'project_name': 'HolstonConnect, LLC - TN - Gigabit (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4314_20230803',
#    'download_available': 'Yes'},
#   {'id': 11521,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4315,
#    'project_name': 'IdeaTek Telcom, LLC - KS - Gigabit (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4315_20230803',
#    'download_available': 'Yes'},
#   {'id': 11522,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4316,
#    'project_name': 'Illinois Electric Cooperative - IL - Above Baseline (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4316_20230803',
#    'download_available': 'Yes'},
#   {'id': 11523,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4317,
#    'project_name': 'Illinois Fiber Connect, LLC - IL - Gigabit (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4317_20230803',
#    'download_available': 'Yes'},
#   {'id': 11512,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4306,
#    'project_name': 'Independent Networks, L.C. - IA - Gigabit (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4306_20230803',
#    'download_available': 'Yes'},
#   {'id': 11513,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4307,
#    'project_name': 'Interstate Telecommunications Cooperative, Inc. - MN - Gigabit (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4307_20230803',
#    'download_available': 'Yes'},
#   {'id': 11514,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4308,
#    'project_name': 'Jaguar Communication, Inc - MN - Gigabit (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4308_20230803',
#    'download_available': 'Yes'},
#   {'id': 11515,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4309,
#    'project_name': 'Lake Region Technology & Communications, LLC - OK - Gigabit (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4309_20230803',
#    'download_available': 'Yes'},
#   {'id': 11516,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4310,
#    'project_name': 'Maquoketa Valley Rural Electric Cooperative - IA - Gigabit (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4310_20230803',
#    'download_available': 'Yes'},
#   {'id': 11517,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4311,
#    'project_name': 'Marshall County Fiber, LLC - IN - Gigabit (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4311_20230803',
#    'download_available': 'Yes'},
#   {'id': 11567,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4363,
#    'project_name': 'Meriwether Lewis Connect LLC - TN - Gigabit (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4363_20230803',
#    'download_available': 'Yes'},
#   {'id': 11569,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4365,
#    'project_name': 'Midcontinent Communications - MN - Above Baseline (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4365_20230803',
#    'download_available': 'Yes'},
#   {'id': 11570,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4366,
#    'project_name': 'Midcontinent Communications - ND - Above Baseline (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4366_20230803',
#    'download_available': 'Yes'},
#   {'id': 11571,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4367,
#    'project_name': 'Midcontinent Communications - SD - Above Baseline (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4367_20230803',
#    'download_available': 'Yes'},
#   {'id': 11568,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4364,
#    'project_name': 'Mid-States Services, LLC - MO - Gigabit (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4364_20230803',
#    'download_available': 'Yes'},
#   {'id': 11572,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4368,
#    'project_name': 'Midwest Energy Cooperative, Inc. - MI - Gigabit (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4368_20230803',
#    'download_available': 'Yes'},
#   {'id': 11573,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4369,
#    'project_name': 'Mountain West Technologies Corporation - WY - Above Baseline (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4369_20230803',
#    'download_available': 'Yes'},
#   {'id': 11574,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4370,
#    'project_name': 'Next, Powered by NAEC, LLC - AR - Gigabit (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4370_20230803',
#    'download_available': 'Yes'},
#   {'id': 11575,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4371,
#    'project_name': 'Northern Arapaho Tribal Industries - WY - Gigabit (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4371_20230803',
#    'download_available': 'Yes'},
#   {'id': 11524,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4318,
#    'project_name': 'Oklahoma Fiber, LLC - OK - Gigabit (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4318_20230803',
#    'download_available': 'Yes'},
#   {'id': 11525,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4319,
#    'project_name': 'Oklahoma Western Telephone Company, Inc. - OK - Gigabit (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4319_20230803',
#    'download_available': 'Yes'},
#   {'id': 11526,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4320,
#    'project_name': 'Orange County REMC - IN - Above Baseline (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4320_20230803',
#    'download_available': 'Yes'},
#   {'id': 11539,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4333,
#    'project_name': 'Orange County REMC - IN - Gigabit (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4333_20230803',
#    'download_available': 'Yes'},
#   {'id': 11540,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4334,
#    'project_name': 'OzarksGo, LLC - AR - Gigabit (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4334_20230803',
#    'download_available': 'Yes'},
#   {'id': 11541,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4335,
#    'project_name': 'OzarksGo, LLC - OK - Gigabit (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4335_20230803',
#    'download_available': 'Yes'},
#   {'id': 11544,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4338,
#    'project_name': 'Paul Bunyan Rural Telephone Cooperative - MN - Gigabit (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4338_20230803',
#    'download_available': 'Yes'},
#   {'id': 11542,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4336,
#    'project_name': 'PC Telcorp, Inc. - CO - Gigabit (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4336_20230803',
#    'download_available': 'Yes'},
#   {'id': 11545,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4339,
#    'project_name': 'Perry-Spencer Rural Telephone Cooperative, Inc. - IN - Gigabit (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4339_20230803',
#    'download_available': 'Yes'},
#   {'id': 11543,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4337,
#    'project_name': 'PGEC Enterprises, LLC - VA - Gigabit (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4337_20230803',
#    'download_available': 'Yes'},
#   {'id': 11546,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
#    'program_name': 'Connect America Fund Phase II',
#    'project_id': 4340,
#    'project_name': 'Pine Cellular Phones, Inc. - OK - Gigabit (Tranche: Phase II)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project4340_20230803',
#    'download_available': 'Yes'},
#   {'id': 11547,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 1,
#    'agency_name': 'Federal Communications Commission',
#    'program_id': 28,
# ...
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project2754_20230803',
#    'download_available': 'Yes'},
#   {'id': 11268,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 3,
#    'agency_name': 'Rural Utilities Service',
#    'program_id': 6,
#    'program_name': 'RURAL ECONNECTIVITY PROGRAM',
#    'project_id': 2823,
#    'project_name': 'Southwest Michigan Communications, Inc.-MI1702-B59/B65 (Tranche: Round 2)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project2823_20230803',
#    'download_available': 'Yes'},
#   {'id': 11375,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 3,
#    'agency_name': 'Rural Utilities Service',
#    'program_id': 6,
#    'program_name': 'RURAL ECONNECTIVITY PROGRAM',
#    'project_id': 2930,
#    'project_name': 'Spring Grove Communications-MN1705-A59 (Tranche: Round 3 (RUS-REC-2022))',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project2930_20230803',
#    'download_available': 'Yes'},
#   {'id': 11188,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 3,
#    'agency_name': 'Rural Utilities Service',
#    'program_id': 6,
#    'program_name': 'RURAL ECONNECTIVITY PROGRAM',
#    'project_id': 2743,
#    'project_name': 'Star Telephone Company, Inc.-LA1701-A59 (Tranche: Round 1)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project2743_20230803',
#    'download_available': 'Yes'},
#   {'id': 11277,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 3,
#    'agency_name': 'Rural Utilities Service',
#    'program_id': 6,
#    'program_name': 'RURAL ECONNECTIVITY PROGRAM',
#    'project_id': 2832,
#    'project_name': 'Star Telephone Company, Inc.-LA1701-B59/B65 (Tranche: Round 2)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project2832_20230803',
#    'download_available': 'Yes'},
#   {'id': 11132,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 3,
#    'agency_name': 'Rural Utilities Service',
#    'program_id': 6,
#    'program_name': 'RURAL ECONNECTIVITY PROGRAM',
#    'project_id': 2687,
#    'project_name': 'Star Telephone Membership Corporation-NC1701-A61 (Tranche: Round 1)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project2687_20230803',
#    'download_available': 'Yes'},
#   {'id': 11245,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 3,
#    'agency_name': 'Rural Utilities Service',
#    'program_id': 6,
#    'program_name': 'RURAL ECONNECTIVITY PROGRAM',
#    'project_id': 2800,
#    'project_name': 'Steelville Telephone Exchange, Incorporated-MO1709-B59/B65 (Tranche: Round 2)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project2800_20230803',
#    'download_available': 'Yes'},
#   {'id': 11247,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 3,
#    'agency_name': 'Rural Utilities Service',
#    'program_id': 6,
#    'program_name': 'RURAL ECONNECTIVITY PROGRAM',
#    'project_id': 2802,
#    'project_name': 'SWC Telesolutions, Incorporated-NM1704-A65 (Tranche: Round 2)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project2802_20230803',
#    'download_available': 'Yes'},
#   {'id': 11407,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 3,
#    'agency_name': 'Rural Utilities Service',
#    'program_id': 6,
#    'program_name': 'RURAL ECONNECTIVITY PROGRAM',
#    'project_id': 2962,
#    'project_name': 'Table Top Telephone Company, Inc.-AZ1705-A65 (Tranche: Round 3 (RUS-REC-2022))',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project2962_20230803',
#    'download_available': 'Yes'},
#   {'id': 11293,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 3,
#    'agency_name': 'Rural Utilities Service',
#    'program_id': 6,
#    'program_name': 'RURAL ECONNECTIVITY PROGRAM',
#    'project_id': 2848,
#    'project_name': 'Tallahatchie Valley Electric Power Association-MS1701-A64 (Tranche: Round 2)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project2848_20230803',
#    'download_available': 'Yes'},
#   {'id': 11297,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 3,
#    'agency_name': 'Rural Utilities Service',
#    'program_id': 6,
#    'program_name': 'RURAL ECONNECTIVITY PROGRAM',
#    'project_id': 2852,
#    'project_name': 'Tatum Telephone Company-TX1704-A64 (Tranche: Round 2)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project2852_20230803',
#    'download_available': 'Yes'},
#   {'id': 11334,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 3,
#    'agency_name': 'Rural Utilities Service',
#    'program_id': 6,
#    'program_name': 'RURAL ECONNECTIVITY PROGRAM',
#    'project_id': 2889,
#    'project_name': 'Taylor Telephone Cooperative, Inc.-TX1708-A59 (Tranche: Round 3 (RUS-REC-2022))',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project2889_20230803',
#    'download_available': 'Yes'},
#   {'id': 11367,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 3,
#    'agency_name': 'Rural Utilities Service',
#    'program_id': 6,
#    'program_name': 'RURAL ECONNECTIVITY PROGRAM',
#    'project_id': 2922,
#    'project_name': 'TEC of Jackson, Inc.-MS1703-A61 (Tranche: Round 3 (RUS-REC-2022))',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project2922_20230803',
#    'download_available': 'Yes'},
#   {'id': 11216,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 3,
#    'agency_name': 'Rural Utilities Service',
#    'program_id': 6,
#    'program_name': 'RURAL ECONNECTIVITY PROGRAM',
#    'project_id': 2771,
#    'project_name': 'Tekstar Communications -MN1707-A73 (Tranche: Round 3 (RUS-REC-2022))',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project2771_20230803',
#    'download_available': 'Yes'},
#   {'id': 11372,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 3,
#    'agency_name': 'Rural Utilities Service',
#    'program_id': 6,
#    'program_name': 'RURAL ECONNECTIVITY PROGRAM',
#    'project_id': 2927,
#    'project_name': 'Teleguam Holdings, LLC-GU1701-A73 (Tranche: Round 3 (RUS-REC-2022))',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project2927_20230803',
#    'download_available': 'Yes'},
#   {'id': 11237,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 3,
#    'agency_name': 'Rural Utilities Service',
#    'program_id': 6,
#    'program_name': 'RURAL ECONNECTIVITY PROGRAM',
#    'project_id': 2792,
#    'project_name': 'Terral Telephone Company-OK1712-A65 (Tranche: Round 2)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project2792_20230803',
#    'download_available': 'Yes'},
#   {'id': 11394,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 3,
#    'agency_name': 'Rural Utilities Service',
#    'program_id': 6,
#    'program_name': 'RURAL ECONNECTIVITY PROGRAM',
#    'project_id': 2949,
#    'project_name': 'Terral Telephone Company-OK1712-B61 (Tranche: Round 3 (RUS-REC-2022))',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project2949_20230803',
#    'download_available': 'Yes'},
#   {'id': 11303,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 3,
#    'agency_name': 'Rural Utilities Service',
#    'program_id': 6,
#    'program_name': 'RURAL ECONNECTIVITY PROGRAM',
#    'project_id': 2858,
#    'project_name': 'Texhoma Fiber, LLC-OK1711-A65 (Tranche: Round 2)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project2858_20230803',
#    'download_available': 'Yes'},
#   {'id': 11308,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 3,
#    'agency_name': 'Rural Utilities Service',
#    'program_id': 6,
#    'program_name': 'RURAL ECONNECTIVITY PROGRAM',
#    'project_id': 2863,
#    'project_name': 'Thacker-Grigsby Telephone Co., Inc.-KY1703-B71 (Tranche: Round 3 (RUS-REC-2022))',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project2863_20230803',
#    'download_available': 'Yes'},
#   {'id': 11171,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 3,
#    'agency_name': 'Rural Utilities Service',
#    'program_id': 6,
#    'program_name': 'RURAL ECONNECTIVITY PROGRAM',
#    'project_id': 2726,
#    'project_name': 'THACKER-GRIGSBY TELEPHONE COMPANY, INCORPORATED-KY1703-A61 (Tranche: Round 1)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project2726_20230803',
#    'download_available': 'Yes'},
#   {'id': 11154,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 3,
#    'agency_name': 'Rural Utilities Service',
#    'program_id': 6,
#    'program_name': 'RURAL ECONNECTIVITY PROGRAM',
#    'project_id': 2709,
#    'project_name': 'The Darien Telephone Co., Inc.-GA1703-A61 (Tranche: Round 1)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project2709_20230803',
#    'download_available': 'Yes'},
#   {'id': 11172,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 3,
#    'agency_name': 'Rural Utilities Service',
#    'program_id': 6,
#    'program_name': 'RURAL ECONNECTIVITY PROGRAM',
#    'project_id': 2727,
#    'project_name': 'THE FARMERS MUTUAL TELEPHONE COMPANY OF STANTON, IOWA-IA1702-A59 (Tranche: Round 1)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project2727_20230803',
#    'download_available': 'Yes'},
#   {'id': 11240,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 3,
#    'agency_name': 'Rural Utilities Service',
#    'program_id': 6,
#    'program_name': 'RURAL ECONNECTIVITY PROGRAM',
#    'project_id': 2795,
#    'project_name': 'THE FARMERS MUTUAL TELEPHONE COMPANY OF STANTON, IOWA-IA1702-B59/B65 (Tranche: Round 2)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project2795_20230803',
#    'download_available': 'Yes'},
#   {'id': 11395,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 3,
#    'agency_name': 'Rural Utilities Service',
#    'program_id': 6,
#    'program_name': 'RURAL ECONNECTIVITY PROGRAM',
#    'project_id': 2950,
#    'project_name': 'The Ponderosa Telephone Co.-CA1702-A59 (Tranche: Round 3 (RUS-REC-2022))',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project2950_20230803',
#    'download_available': 'Yes'},
#   {'id': 11131,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 3,
#    'agency_name': 'Rural Utilities Service',
#    'program_id': 6,
#    'program_name': 'RURAL ECONNECTIVITY PROGRAM',
#    'project_id': 2686,
#    'project_name': 'The Stoutland Telephone Company-MO1708-B65 (Tranche: Round 2)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project2686_20230803',
#    'download_available': 'Yes'},
#   {'id': 11329,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 3,
#    'agency_name': 'Rural Utilities Service',
#    'program_id': 6,
#    'program_name': 'RURAL ECONNECTIVITY PROGRAM',
#    'project_id': 2884,
#    'project_name': 'The Volcano Telephone Company-CA1701-A60 (Tranche: Round 3 (RUS-REC-2022))',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project2884_20230803',
#    'download_available': 'Yes'},
#   {'id': 11233,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 3,
#    'agency_name': 'Rural Utilities Service',
#    'program_id': 6,
#    'program_name': 'RURAL ECONNECTIVITY PROGRAM',
#    'project_id': 2788,
#    'project_name': 'Tipmont Rural Electric Membership Corporation-IN1701-A65 (Tranche: Round 2)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project2788_20230803',
#    'download_available': 'Yes'},
#   {'id': 11398,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 3,
#    'agency_name': 'Rural Utilities Service',
#    'program_id': 6,
#    'program_name': 'RURAL ECONNECTIVITY PROGRAM',
#    'project_id': 2953,
#    'project_name': "Tohono O'odham Utility Authority-AZ1704-A61 (Tranche: Round 3 (RUS-REC-2022))",
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project2953_20230803',
#    'download_available': 'Yes'},
#   {'id': 11186,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 3,
#    'agency_name': 'Rural Utilities Service',
#    'program_id': 6,
#    'program_name': 'RURAL ECONNECTIVITY PROGRAM',
#    'project_id': 2741,
#    'project_name': 'Tombigbee Electric Cooperative, Inc.-AL1702-A59 (Tranche: Round 1)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project2741_20230803',
#    'download_available': 'Yes'},
#   {'id': 11133,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 3,
#    'agency_name': 'Rural Utilities Service',
#    'program_id': 6,
#    'program_name': 'RURAL ECONNECTIVITY PROGRAM',
#    'project_id': 2688,
#    'project_name': 'Total Highspeed LLC-MO1702-A59 (Tranche: Round 1)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project2688_20230803',
#    'download_available': 'Yes'},
#   {'id': 11222,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 3,
#    'agency_name': 'Rural Utilities Service',
#    'program_id': 6,
#    'program_name': 'RURAL ECONNECTIVITY PROGRAM',
#    'project_id': 2777,
#    'project_name': 'Total Highspeed LLC-MO1702-C59/C65 (Tranche: Round 2)',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project2777_20230803',
#    'download_available': 'Yes'},
#   {'id': 11352,
#    'data_category': 'Funding Data',
#    'data_type': 'Project',
#    'agency_id': 3,
#    'agency_name': 'Rural Utilities Service',
#    'program_id': 6,
#    'program_name': 'RURAL ECONNECTIVITY PROGRAM',
#    'project_id': 2907,
#    'project_name': 'Totelcom Communications, LLC-TX1707-A61 (Tranche: Round 3 (RUS-REC-2022))',
#    'state_fips': None,
#    'state_name': None,
#    'file_type': 'csv',
#    'modified_date': None,
#    'file_name': 'fundingdata_project2907_20230803',
#    'download_available': 'Yes'},
#   ...],
#  'result_count': 1117,
#  'status_code': 200,
#  'message': None,
#  'status': 'successful',
#  'request_date': '2023-08-03T17:37:03.857Z'}

# %%
programs = {item['program_name'] for item in parsed['data']}

# %%
programs
# Out:
# {'Bringing Puerto Rico Together',
#  'Broadband Infrastructure Program',
#  'COMMUNITY CONNECT GRANT PROGRAM',
#  'Capital Projects Fund',
#  'Connect America Fund Phase II',
#  'Connect USVI',
#  None,
#  'RURAL ECONNECTIVITY PROGRAM',
#  'Rural Digital Opportunity Fund',
#  'TELEPHONE LOAN PROGRAM',
#  'Tribal Broadband Connectivity Program NOFO 1'}

# %% [markdown]
# Let's jump into pandas and dig a little deeper.

# %%
df = pd.DataFrame(parsed['data'])

# %% [markdown]
# Here is the whole table. Feel free to search it for specific programs.

# %%
itables.show(df)
# Out:
# <style>.itables table td {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables table th {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables thead input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
#
# .itables tfoot input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
# </style>
# <div class="itables">
# <table id="4a76531d-c317-4924-b5bd-d593ddfec797" class="display nowrap"style="table-layout:auto;width:auto;margin:auto;caption-side:bottom"><thead>
#     <tr style="text-align: right;">
#
#       <th>id</th>
#       <th>data_category</th>
#       <th>data_type</th>
#       <th>agency_id</th>
#       <th>agency_name</th>
#       <th>program_id</th>
#       <th>program_name</th>
#       <th>project_id</th>
#       <th>project_name</th>
#       <th>state_fips</th>
#       <th>state_name</th>
#       <th>file_type</th>
#       <th>modified_date</th>
#       <th>file_name</th>
#       <th>download_available</th>
#     </tr>
#   </thead><tbody><tr><td>Loading... (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td></tr></tbody></table>
# <script>
#     // We use a namespace per table (= the next curly bracket)
#     // to avoid conflicts between the various tables' data & dt_args
#     {
#         // Define the table data
#         const data = [[11036, "Funding Data", "Program", 1.0, "Federal Communications Commission", 25.0, "Bringing Puerto Rico Together", NaN, "None", "None", "None", "csv", "None", "fundingdata_program25_20230803", "Yes"], [11041, "Funding Data", "Program", 1.0, "Federal Communications Commission", 28.0, "Connect America Fund Phase II", NaN, "None", "None", "None", "csv", "None", "fundingdata_program28_20230803", "Yes"], [11037, "Funding Data", "Program", 1.0, "Federal Communications Commission", 26.0, "Connect USVI", NaN, "None", "None", "None", "csv", "None", "fundingdata_program26_20230803", "Yes"], [11042, "Funding Data", "Program", 1.0, "Federal Communications Commission", 24.0, "Rural Digital Opportunity Fund", NaN, "None", "None", "None", "csv", "None", "fundingdata_program24_20230803", "Yes"], [11039, "Funding Data", "Program", 5.0, "NTIA", 11.0, "Broadband Infrastructure Program", NaN, "None", "None", "None", "csv", "None", "fundingdata_program11_20230803", "Yes"], [11040, "Funding Data", "Program", 5.0, "NTIA", 27.0, "Tribal Broadband Connectivity Program NOFO 1", NaN, "None", "None", "None", "csv", "None", "fundingdata_program27_20230803", "Yes"], [11038, "Funding Data", "Program", 3.0, "Rural Utilities Service", 10.0, "COMMUNITY CONNECT GRANT PROGRAM", NaN, "None", "None", "None", "csv", "None", "fundingdata_program10_20230803", "Yes"], [11035, "Funding Data", "Program", 3.0, "Rural Utilities Service", 6.0, "RURAL ECONNECTIVITY PROGRAM", NaN, "None", "None", "None", "csv", "None", "fundingdata_program6_20230803", "Yes"], [11033, "Funding Data", "Program", 3.0, "Rural Utilities Service", 12.0, "TELEPHONE LOAN PROGRAM", NaN, "None", "None", "None", "csv", "None", "fundingdata_program12_20230803", "Yes"], [11034, "Funding Data", "Program", 4.0, "US Department of Treasury", 18.0, "Capital Projects Fund", NaN, "None", "None", "None", "csv", "None", "fundingdata_program18_20230803", "Yes"], [11466, "Funding Data", "Project", 1.0, "Federal Communications Commission", 25.0, "Bringing Puerto Rico Together", 4259.0, "Liberty Communications - PR - Above Baseline (Tranche: Stage 2)", "None", "None", "csv", "None", "fundingdata_project4259_20230803", "Yes"], [11467, "Funding Data", "Project", 1.0, "Federal Communications Commission", 25.0, "Bringing Puerto Rico Together", 4260.0, "Liberty Communications - PR - Gigabit (Tranche: Stage 2)", "None", "None", "csv", "None", "fundingdata_project4260_20230803", "Yes"], [11468, "Funding Data", "Project", 1.0, "Federal Communications Commission", 25.0, "Bringing Puerto Rico Together", 4261.0, "Puerto Rico Telephone Co. - PR - Above Baseline (Tranche: Stage 2)", "None", "None", "csv", "None", "fundingdata_project4261_20230803", "Yes"], [11469, "Funding Data", "Project", 1.0, "Federal Communications Commission", 25.0, "Bringing Puerto Rico Together", 4262.0, "Puerto Rico Telephone Co. - PR - Gigabit (Tranche: Stage 2)", "None", "None", "csv", "None", "fundingdata_project4262_20230803", "Yes"], [11470, "Funding Data", "Project", 1.0, "Federal Communications Commission", 28.0, "Connect America Fund Phase II", 4263.0, "3E8 Broadband Solutions, LLC - AR - Gigabit (Tranche: Phase II)", "None", "None", "csv", "None", "fundingdata_project4263_20230803", "Yes"], [11477, "Funding Data", "Project", 1.0, "Federal Communications Commission", 28.0, "Connect America Fund Phase II", 4270.0, "Air Link Rural Broadband, LLC - MO - Above Baseline (Tranche: Phase II)", "None", "None", "csv", "None", "fundingdata_project4270_20230803", "Yes"], [11478, "Funding Data", "Project", 1.0, "Federal Communications Commission", 28.0, "Connect America Fund Phase II", 4271.0, "Allen's T.V. Cable Service, Inc. - LA - Gigabit (Tranche: Phase II)", "None", "None", "csv", "None", "fundingdata_project4271_20230803", "Yes"], [11471, "Funding Data", "Project", 1.0, "Federal Communications Commission", 28.0, "Connect America Fund Phase II", 4264.0, "AMG Technology Investment Group LLC - IA - Above Baseline (Tranche: Phase II)" ...

# %% [markdown]
# Quick EDA

# %%
df.data_category.value_counts()

df[df.data_category == 'Unserved-Unfunded']
# Out:
#          id      data_category data_type  agency_id agency_name  program_id  \
# 1063  10979  Unserved-Unfunded     State        NaN        None         NaN
# 1064  10980  Unserved-Unfunded     State        NaN        None         NaN
# 1065  10981  Unserved-Unfunded     State        NaN        None         NaN
# 1066  10982  Unserved-Unfunded     State        NaN        None         NaN
# 1067  10983  Unserved-Unfunded     State        NaN        None         NaN
# 1068  10984  Unserved-Unfunded     State        NaN        None         NaN
# 1069  10985  Unserved-Unfunded     State        NaN        None         NaN
# 1070  10986  Unserved-Unfunded     State        NaN        None         NaN
# 1071  10987  Unserved-Unfunded     State        NaN        None         NaN
# 1072  10988  Unserved-Unfunded     State        NaN        None         NaN
# 1073  10989  Unserved-Unfunded     State        NaN        None         NaN
# 1074  10990  Unserved-Unfunded     State        NaN        None         NaN
# 1075  10991  Unserved-Unfunded     State        NaN        None         NaN
# 1076  10992  Unserved-Unfunded     State        NaN        None         NaN
# 1077  10993  Unserved-Unfunded     State        NaN        None         NaN
# 1078  10994  Unserved-Unfunded     State        NaN        None         NaN
# 1079  10995  Unserved-Unfunded     State        NaN        None         NaN
# 1080  10996  Unserved-Unfunded     State        NaN        None         NaN
# 1081  10997  Unserved-Unfunded     State        NaN        None         NaN
# 1082  10998  Unserved-Unfunded     State        NaN        None         NaN
# 1083  10999  Unserved-Unfunded     State        NaN        None         NaN
# 1084  11000  Unserved-Unfunded     State        NaN        None         NaN
# 1085  11001  Unserved-Unfunded     State        NaN        None         NaN
# 1086  11002  Unserved-Unfunded     State        NaN        None         NaN
# 1087  11003  Unserved-Unfunded     State        NaN        None         NaN
# 1088  11004  Unserved-Unfunded     State        NaN        None         NaN
# 1089  11005  Unserved-Unfunded     State        NaN        None         NaN
# 1090  11006  Unserved-Unfunded     State        NaN        None         NaN
# 1091  11007  Unserved-Unfunded     State        NaN        None         NaN
# 1092  11008  Unserved-Unfunded     State        NaN        None         NaN
# 1093  11009  Unserved-Unfunded     State        NaN        None         NaN
# 1094  11010  Unserved-Unfunded     State        NaN        None         NaN
# 1095  11011  Unserved-Unfunded     State        NaN        None         NaN
# 1096  11012  Unserved-Unfunded     State        NaN        None         NaN
# 1097  11013  Unserved-Unfunded     State        NaN        None         NaN
# 1098  11014  Unserved-Unfunded     State        NaN        None         NaN
# 1099  11015  Unserved-Unfunded     State        NaN        None         NaN
# 1100  11016  Unserved-Unfunded     State        NaN        None         NaN
# 1101  11017  Unserved-Unfunded     State        NaN        None         NaN
# 1102  11018  Unserved-Unfunded     State        NaN        None         NaN
# 1103  11019  Unserved-Unfunded     State        NaN        None         NaN
# 1104  11020  Unserved-Unfunded     State        NaN        None         NaN
# 1105  11021  Unserved-Unfunded     State        NaN        None         NaN
# 1106  11022  Unserved-Unfunded     State        NaN        None         NaN
# 1107  11023  Unserved-Unfunded     State        NaN        None         NaN
# 1108  11024  Unserved-Unfunded     State        NaN        None         NaN
# 1109  11025  Unserved-Unfunded     State        NaN        None         NaN
# 1110  11026  Unserved-Unfunded     State        NaN        None         NaN
# 1111  11027  Unserved-Unfunded     State        NaN        None         NaN
# 1112  11028  Unserved-Unfunded     State        NaN        None         NaN
# 1113  11029  Unserved-Unfunded     State        NaN        None         NaN
# 1114  11030  Unserved-Unfunded     State        NaN        None         NaN
# 1115  11031  Unserved-Unfunded     State        NaN        None         NaN
# 1116  11032  Unserved-Unfunded     State        NaN        None         NaN
#
#      program_name  project_id project_name state_fips  \
# 1063         None         NaN         None         01
# 1064         None         NaN         None         02
# 1065         None         NaN         None         04
# 1066         None         NaN         None         05
# 1067         None         NaN         None         06
# 1068         None         NaN         None         08
# 1069         None         NaN         None         09
# 1070         None         NaN         None         10
# 1071         None         NaN         None         11
# 1072         None         NaN         None         12
# 1073         None         NaN         None         13
# 1074         None         NaN         None         15
# 1075         None         NaN         None         16
# 1076         None         NaN         None         17
# 1077         None         NaN         None         18
# 1078         None         NaN         None         19
# 1079         None         NaN         None         20
# 1080         None         NaN         None         21
# 1081         None         NaN         None         22
# 1082         None         NaN         None         23
# 1083         None         NaN         None         24
# 1084         None         NaN         None         25
# 1085         None         NaN         None         26
# 1086         None         NaN         None         27
# 1087         None         NaN         None         28
# 1088         None         NaN         None         29
# 1089         None         NaN         None         30
# 1090         None         NaN         None         31
# 1091         None         NaN         None         32
# 1092         None         NaN         None         33
# 1093         None         NaN         None         34
# 1094         None         NaN         None         35
# 1095         None         NaN         None         36
# 1096         None         NaN         None         37
# 1097         None         NaN         None         38
# 1098         None         NaN         None         39
# 1099         None         NaN         None         40
# 1100         None         NaN         None         41
# 1101         None         NaN         None         42
# 1102         None         NaN         None         44
# 1103         None         NaN         None         45
# 1104         None         NaN         None         46
# 1105         None         NaN         None         47
# 1106         None         NaN         None         48
# 1107         None         NaN         None         49
# 1108         None         NaN         None         50
# 1109         None         NaN         None         51
# 1110         None         NaN         None         53
# 1111         None         NaN         None         54
# 1112         None         NaN         None         55
# 1113         None         NaN         None         56
# 1114         None         NaN         None         60
# 1115         None         NaN         None         66
# 1116         None         NaN         None         69
#
#                                         state_name file_type modified_date  \
# 1063                                       Alabama       csv          None
# 1064                                        Alaska       csv          None
# 1065                                       Arizona       csv          None
# 1066                                      Arkansas       csv          None
# 1067                                    California       csv          None
# 1068                                      Colorado       csv          None
# 1069                                   Connecticut       csv          None
# 1070                                      Delaware       csv          None
# 1071                          District of Columbia       csv          None
# 1072                                       Florida       csv          None
# 1073                                       Georgia       csv          None
# 1074                                        Hawaii       csv          None
# 1075                                         Idaho       csv          None
# 1076                                      Illinois       csv          None
# 1077                                       Indiana       csv          None
# 1078                                          Iowa       csv          None
# 1079                                        Kansas       csv          None
# 1080                                      Kentucky       csv          None
# 1081                                     Louisiana       csv          None
# 1082                                         Maine       csv          None
# 1083                                      Maryland       csv          None
# 1084                                 Massachusetts       csv          None
# 1085                                      Michigan       csv          None
# 1086                                     Minnesota       csv          None
# 1087                                   Mississippi       csv          None
# 1088                                      Missouri       csv          None
# 1089                                       Montana       csv          None
# 1090                                      Nebraska       csv          None
# 1091                                        Nevada       csv          None
# 1092                                 New Hampshire       csv          None
# 1093                                    New Jersey       csv          None
# 1094                                    New Mexico       csv          None
# 1095                                      New York       csv          None
# 1096                                North Carolina       csv          None
# 1097                                  North Dakota       csv          None
# 1098                                          Ohio       csv          None
# 1099                                      Oklahoma       csv          None
# 1100                                        Oregon       csv          None
# 1101                                  Pennsylvania       csv          None
# 1102                                  Rhode Island       csv          None
# 1103                                South Carolina       csv          None
# 1104                                  South Dakota       csv          None
# 1105                                     Tennessee       csv          None
# 1106                                         Texas       csv          None
# 1107                                          Utah       csv          None
# 1108                                       Vermont       csv          None
# 1109                                      Virginia       csv          None
# 1110                                    Washington       csv          None
# 1111                                 West Virginia       csv          None
# 1112                                     Wisconsin       csv          None
# 1113                                       Wyoming       csv          None
# 1114                                American Samoa       csv          None
# 1115                                          Guam       csv          None
# 1116  Commonwealth of the Northern Mariana Islands       csv          None
#
#                                file_name download_available
# 1063  state01_unserved_unfunded_20230803                Yes
# 1064  state02_unserved_unfunded_20230803                Yes
# 1065  state04_unserved_unfunded_20230803                Yes
# 1066  state05_unserved_unfunded_20230803                Yes
# 1067  state06_unserved_unfunded_20230803                Yes
# 1068  state08_unserved_unfunded_20230803                Yes
# 1069  state09_unserved_unfunded_20230803                Yes
# 1070  state10_unserved_unfunded_20230803                Yes
# 1071  state11_unserved_unfunded_20230803                Yes
# 1072  state12_unserved_unfunded_20230803                Yes
# 1073  state13_unserved_unfunded_20230803                Yes
# 1074  state15_unserved_unfunded_20230803                Yes
# 1075  state16_unserved_unfunded_20230803                Yes
# 1076  state17_unserved_unfunded_20230803                Yes
# 1077  state18_unserved_unfunded_20230803                Yes
# 1078  state19_unserved_unfunded_20230803                Yes
# 1079  state20_unserved_unfunded_20230803                Yes
# 1080  state21_unserved_unfunded_20230803                Yes
# 1081  state22_unserved_unfunded_20230803                Yes
# 1082  state23_unserved_unfunded_20230803                Yes
# 1083  state24_unserved_unfunded_20230803                Yes
# 1084  state25_unserved_unfunded_20230803                Yes
# 1085  state26_unserved_unfunded_20230803                Yes
# 1086  state27_unserved_unfunded_20230803                Yes
# 1087  state28_unserved_unfunded_20230803                Yes
# 1088  state29_unserved_unfunded_20230803                Yes
# 1089  state30_unserved_unfunded_20230803                Yes
# 1090  state31_unserved_unfunded_20230803                Yes
# 1091  state32_unserved_unfunded_20230803                Yes
# 1092  state33_unserved_unfunded_20230803                Yes
# 1093  state34_unserved_unfunded_20230803                Yes
# 1094  state35_unserved_unfunded_20230803                Yes
# 1095  state36_unserved_unfunded_20230803                Yes
# 1096  state37_unserved_unfunded_20230803                Yes
# 1097  state38_unserved_unfunded_20230803                Yes
# 1098  state39_unserved_unfunded_20230803                Yes
# 1099  state40_unserved_unfunded_20230803                Yes
# 1100  state41_unserved_unfunded_20230803                Yes
# 1101  state42_unserved_unfunded_20230803                Yes
# 1102  state44_unserved_unfunded_20230803                Yes
# 1103  state45_unserved_unfunded_20230803                Yes
# 1104  state46_unserved_unfunded_20230803                Yes
# 1105  state47_unserved_unfunded_20230803                Yes
# 1106  state48_unserved_unfunded_20230803                Yes
# 1107  state49_unserved_unfunded_20230803                Yes
# 1108  state50_unserved_unfunded_20230803                Yes
# 1109  state51_unserved_unfunded_20230803                Yes
# 1110  state53_unserved_unfunded_20230803                Yes
# 1111  state54_unserved_unfunded_20230803                Yes
# 1112  state55_unserved_unfunded_20230803                Yes
# 1113  state56_unserved_unfunded_20230803                Yes
# 1114  state60_unserved_unfunded_20230803                Yes
# 1115  state66_unserved_unfunded_20230803                Yes
# 1116  state69_unserved_unfunded_20230803                Yes

# %% [markdown]
# Pulling out the Unserved-Unfunded data shows us these are the state level files. These are pretty straightforward.
